# %% [markdown]
# # matplotlib 공부 (1)
#
# 이정민
# 2025-09-02

# %%
import matplotlib.pyplot as plt

# %%
y1= [1.0, 2.0, 3.0, 4.0]
y2= [1.1, 2.2, 2.8, 0.0]
plt.plot(y1,'--o',label='y1')
plt.plot(y2,'--o',label='y2')
plt.legend()
